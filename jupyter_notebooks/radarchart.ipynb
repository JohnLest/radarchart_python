# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
def get_radar_area(dataframe, col):
    labels = list(dataframe.columns)
    alpha = 360 / len(labels)
    area = 0
    for elem in enumerate(dataframe):
        side = (dataframe[labels[elem[0]]][col], dataframe[labels[(elem[0] + 1) % len(labels)]][col])
        area = area + (0.5 * side[0] * side[1] * math.sin(math.radians(alpha)))
    return area

# %%
data_df = pd.read_csv("../data/teaching_skills.csv", index_col="date")
data_df
# Out:
#                 pedagogy  communication  adaptation  authority  \
# date
# 2022-september         6              8           7          6
#
#                 emotion_management  tolerance  passion  knowledge  creativity  \
# date
# 2022-september                   5          9        9          8           6
#
#                 synthesize
# date
# 2022-september           5

# %%
labels = list(data_df.columns)
values = data_df.loc["2022-september"].tolist()
num_vars = len(labels)
angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
values += values[:1]
angles += angles[:1]
fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))
ax.set_theta_offset(np.pi / 2)
ax.set_theta_direction(-1)
ax.set_thetagrids(np.degrees(angles[:-1]), labels)
ax.set_ylim(0, 10)
ax.set_rgrids([e for e in range(11)])
ax.set_rlabel_position(180 / num_vars)
ax.plot(angles, values, color='red', linewidth=1)
ax.fill(angles, values, color='red', alpha=0.25)

# %%
area_radar = get_radar_area(data_df, "2022-september")
area_radar
# Out:
# 141.65624580248607

# %%
june_df = pd.read_csv("../data/teaching_skills_june.csv", index_col="date")
june_df
# Out:
#            student_management  parent_management  time_management  \
# date
# 2023-June                   6                  4                2
#
#            emotion_management  classroom_climate_management  adaptation  \
# date
# 2023-June                   5                             6           6
#
#            tolerance  passion  knowledge  constructivism
# date
# 2023-June          7        8          8               6

# %%
labels = list(june_df.columns)
values = june_df.loc["2023-June"].tolist()
num_vars = len(labels)
angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
values += values[:1]
angles += angles[:1]
fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))
ax.set_theta_offset(np.pi / 2)
ax.set_theta_direction(-1)
ax.set_thetagrids(np.degrees(angles[:-1]), labels)
ax.set_ylim(0, 10)
ax.set_rgrids([e for e in range(11)])
ax.set_rlabel_position(180 / num_vars)
ax.plot(angles, values, color='red', linewidth=1)
ax.fill(angles, values, color='red', alpha=0.25)

# %%
area_radar = get_radar_area(june_df, "2023-June")
area_radar
# Out:
# 104.03798965576775
